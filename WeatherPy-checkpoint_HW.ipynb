# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
api_key = "f63091978fbd2a8bf514153da1a47cac"
target_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
city = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
maxtemp = []
windspeed = []

record = 1

print(f"Beginning Data Retrieval")
print(f"-------------------------------")

for city in cities:  
    
    try: 
        response = requests.get(f"{target_url}&q={city}").json() 
        city.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{target_url}&q={city}")
        
        record= record + 1
        
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# City not found. Skipping...
# Processing Record 1 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=mehamn
# Processing Record 2 | Talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=talcahuano
# Processing Record 3 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=barrow
# Processing Record 4 | Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=yerbogachen
# Processing Record 5 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=avarua
# Processing Record 6 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=mahebourg
# Processing Record 7 | Champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=champerico
# Processing Record 8 | San Luis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=san luis
# Processing Record 9 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ushuaia
# Processing Record 10 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=jamestown
# Processing Record 11 | Port Augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=port augusta
# Processing Record 12 | Calvinia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=calvinia
# City not found. Skipping...
# Processing Record 13 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kapaa
# Processing Record 14 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hamilton
# Processing Record 15 | Sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=sola
# Processing Record 16 | Winslow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=winslow
# Processing Record 17 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=albany
# Processing Record 18 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=vaini
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=cabo san lucas
# Processing Record 20 | Arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=arman
# Processing Record 21 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=mataura
# Processing Record 22 | Siniscola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=siniscola
# Processing Record 23 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=bluff
# Processing Record 24 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ribeira grande
# Processing Record 25 | Alta Floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=alta floresta
# Processing Record 26 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kavaratti
# Processing Record 27 | Cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=cairns
# City not found. Skipping...
# Processing Record 28 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=busselton
# Processing Record 29 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=geraldton
# Processing Record 30 | Anuradhapura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=anuradhapura
# City not found. Skipping...
# Processing Record 31 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hilo
# Processing Record 32 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=port elizabeth
# Processing Record 33 | Beruwala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=beruwala
# Processing Record 34 | Moose Factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=moose factory
# Processing Record 35 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=puerto ayora
# Processing Record 36 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=port alfred
# Processing Record 37 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=klaksvik
# Processing Record 38 | Vanderhoof
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=vanderhoof
# City not found. Skipping...
# Processing Record 39 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=bredasdorp
# Processing Record 40 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=esperance
# Processing Record 41 | San Carlos de Bariloche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=san carlos de bariloche
# Processing Record 42 | Poya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=poya
# Processing Record 43 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=bubaque
# Processing Record 44 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=airai
# City not found. Skipping...
# Processing Record 45 | Yuzhno-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=yuzhno-kurilsk
# Processing Record 46 | Kingsteignton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kingsteignton
# Processing Record 47 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hithadhoo
# Processing Record 48 | Dandong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=dandong
# Processing Record 49 | Mhlume
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=mhlume
# Processing Record 50 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=coquimbo
# Processing Record 51 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=tura
# Processing Record 52 | Patti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=patti
# Processing Record 53 | Morwell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=morwell
# City not found. Skipping...
# Processing Record 54 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=leningradskiy
# Processing Record 55 | Novyy Khushet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=novyy khushet
# Processing Record 56 | Xifeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=xifeng
# Processing Record 57 | Mackenzie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=mackenzie
# Processing Record 58 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=khatanga
# Processing Record 59 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=dingle
# Processing Record 60 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=torbay
# Processing Record 61 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=tuktoyaktuk
# Processing Record 62 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=talnakh
# Processing Record 63 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=faya
# Processing Record 64 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=upernavik
# Processing Record 65 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=dikson
# City not found. Skipping...
# Processing Record 66 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=punta arenas
# Processing Record 67 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=grindavik
# Processing Record 68 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=okhotsk
# Processing Record 69 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=chokurdakh
# Processing Record 70 | Ratnagiri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ratnagiri
# Processing Record 71 | Lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=lasa
# Processing Record 72 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ambilobe
# Processing Record 73 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=caravelas
# Processing Record 74 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=butaritari
# Processing Record 75 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=bethel
# Processing Record 76 | Qostanay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=qostanay
# Processing Record 77 | Dzaoudzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=dzaoudzi
# Processing Record 78 | Ilhabela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ilhabela
# Processing Record 79 | Birao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=birao
# Processing Record 80 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kahului
# Processing Record 81 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=longyearbyen
# Processing Record 82 | Acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=acapulco
# Processing Record 83 | Mollendo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=mollendo
# Processing Record 84 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=san patricio
# Processing Record 85 | Sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=sisimiut
# Processing Record 86 | Kysyl-Syr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kysyl-syr
# City not found. Skipping...
# Processing Record 87 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=thompson
# Processing Record 88 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=cape town
# Processing Record 89 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=labuhan
# Processing Record 90 | Muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=muros
# Processing Record 91 | Solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=solnechnyy
# Processing Record 92 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=arraial do cabo
# City not found. Skipping...
# Processing Record 93 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hasaki
# Processing Record 94 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=salalah
# Processing Record 95 | Yangambi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=yangambi
# Processing Record 96 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=bambous virieux
# Processing Record 97 | Grand-Lahou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=grand-lahou
# Processing Record 98 | Heihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=heihe
# Processing Record 99 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=atuona
# Processing Record 100 | Altay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=altay
# Processing Record 101 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=rikitea
# Processing Record 102 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=faanui
# Processing Record 103 | Aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=aswan
# Processing Record 104 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=georgetown
# Processing Record 105 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=nanortalik
# Processing Record 106 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ostrovnoy
# Processing Record 107 | Vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=vila
# Processing Record 108 | Beidao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=beidao
# Processing Record 109 | Tequixquitla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=tequixquitla
# Processing Record 110 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=tiksi
# Processing Record 111 | Aktau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=aktau
# Processing Record 112 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=cherskiy
# Processing Record 113 | Tateyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=tateyama
# Processing Record 114 | Mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=mitsamiouli
# Processing Record 115 | Meadow Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=meadow lake
# Processing Record 116 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=lompoc
# City not found. Skipping...
# Processing Record 117 | Olga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=olga
# Processing Record 118 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=vardo
# Processing Record 119 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=tasiilaq
# Processing Record 120 | Ust-Nera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ust-nera
# Processing Record 121 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ponta do sol
# Processing Record 122 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kavieng
# Processing Record 123 | Mnogovershinnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=mnogovershinnyy
# Processing Record 124 | Evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=evensk
# Processing Record 125 | Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=marawi
# Processing Record 126 | Araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=araouane
# City not found. Skipping...
# Processing Record 127 | Blonay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=blonay
# Processing Record 128 | Ust-Tsilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ust-tsilma
# City not found. Skipping...
# Processing Record 129 | Hervey Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hervey bay
# Processing Record 130 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hermanus
# Processing Record 131 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=port lincoln
# Processing Record 132 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=nikolskoye
# Processing Record 133 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=yellowknife
# Processing Record 134 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=laguna
# Processing Record 135 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=provideniya
# City not found. Skipping...
# Processing Record 136 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=husavik
# Processing Record 137 | Vega de Alatorre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=vega de alatorre
# Processing Record 138 | Itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=itoman
# Processing Record 139 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=yulara
# Processing Record 140 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kruisfontein
# Processing Record 141 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=fairbanks
# City not found. Skipping...
# Processing Record 142 | Hof
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hof
# Processing Record 143 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=souillac
# City not found. Skipping...
# Processing Record 144 | Antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=antalaha
# Processing Record 145 | Ust-Kuyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ust-kuyga
# Processing Record 146 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=yar-sale
# Processing Record 147 | Broken Hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=broken hill
# Processing Record 148 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=sioux lookout
# Processing Record 149 | Axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=axim
# Processing Record 150 | Gali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=gali
# Processing Record 151 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=beringovskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 152 | Kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kiama
# Processing Record 153 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=qaanaaq
# Processing Record 154 | Krasnogvardeyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=krasnogvardeyskiy
# Processing Record 155 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=iqaluit
# Processing Record 156 | Lalpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=lalpur
# Processing Record 157 | Vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=vestmanna
# Processing Record 158 | Viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=viedma
# Processing Record 159 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=cidreira
# Processing Record 160 | Hay River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hay river
# Processing Record 161 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=srednekolymsk
# Processing Record 162 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=riyadh
# Processing Record 163 | Kargasok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kargasok
# Processing Record 164 | Belaya Gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=belaya gora
# Processing Record 165 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kununurra
# Processing Record 166 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=lebu
# Processing Record 167 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=fort nelson
# Processing Record 168 | Mabaruma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=mabaruma
# Processing Record 169 | Santa Rosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=santa rosa
# Processing Record 170 | Homer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=homer
# Processing Record 171 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hobart
# Processing Record 172 | Kazerun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kazerun
# Processing Record 173 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=vila franca do campo
# Processing Record 174 | Mazarron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=mazarron
# Processing Record 175 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=norman wells
# Processing Record 176 | Tigil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=tigil
# Processing Record 177 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=paamiut
# City not found. Skipping...
# Processing Record 178 | Koumac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=koumac
# Processing Record 179 | Iralaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=iralaya
# City not found. Skipping...
# Processing Record 180 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kodiak
# Processing Record 181 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=margate
# City not found. Skipping...
# Processing Record 182 | Shizunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=shizunai
# Processing Record 183 | Livingston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=livingston
# Processing Record 184 | Abalak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=abalak
# Processing Record 185 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=castro
# Processing Record 186 | Morristown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=morristown
# Processing Record 187 | Barcelos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=barcelos
# Processing Record 188 | Moussoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=moussoro
# Processing Record 189 | Swan River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=swan river
# Processing Record 190 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=buala
# Processing Record 191 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=cockburn town
# Processing Record 192 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=port hedland
# Processing Record 193 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=saskylakh
# Processing Record 194 | Ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ulladulla
# Processing Record 195 | Rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=rocha
# City not found. Skipping...
# Processing Record 196 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=chuy
# City not found. Skipping...
# Processing Record 197 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=lagoa
# Processing Record 198 | Pardina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=pardina
# Processing Record 199 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=luderitz
# City not found. Skipping...
# Processing Record 200 | Zhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=zhangye
# Processing Record 201 | Piney Green
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=piney green
# Processing Record 202 | Hearst
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hearst
# Processing Record 203 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=saldanha
# Processing Record 204 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=avera
# Processing Record 205 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=saint george
# Processing Record 206 | Puerto del Rosario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=puerto del rosario
# Processing Record 207 | Inyonga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=inyonga
# Processing Record 208 | Boa Vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=boa vista
# Processing Record 209 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=camacha
# Processing Record 210 | Sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=sabang
# Processing Record 211 | Illela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=illela
# Processing Record 212 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=alofi
# Processing Record 213 | Burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=burnie
# Processing Record 214 | Chunoyar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=chunoyar
# Processing Record 215 | Nkoteng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=nkoteng
# Processing Record 216 | Montepuez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=montepuez
# Processing Record 217 | Sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=sambava
# Processing Record 218 | Svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=svetlogorsk
# Processing Record 219 | Sokoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=sokoni
# Processing Record 220 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=inhambane
# Processing Record 221 | Unity
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=unity
# Processing Record 222 | Kidal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kidal
# City not found. Skipping...
# Processing Record 223 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=pevek
# Processing Record 224 | Antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=antofagasta
# Processing Record 225 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kieta
# Processing Record 226 | Belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=belmonte
# Processing Record 227 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hualmay
# Processing Record 228 | Cotonou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=cotonou
# Processing Record 229 | Kungurtug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kungurtug
# Processing Record 230 | Gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=gizo
# Processing Record 231 | Cuamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=cuamba
# Processing Record 232 | Kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kenai
# Processing Record 233 | Puerto Ayacucho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=puerto ayacucho
# Processing Record 234 | Alenquer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=alenquer
# Processing Record 235 | Kaliua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kaliua
# Processing Record 236 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=sao filipe
# Processing Record 237 | Sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=sechura
# Processing Record 238 | Cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=cabedelo
# Processing Record 239 | Plettenberg Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=plettenberg bay
# Processing Record 240 | Lagos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=lagos
# Processing Record 241 | Xam Nua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=xam nua
# Processing Record 242 | Bardejov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=bardejov
# City not found. Skipping...
# Processing Record 243 | Milledgeville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=milledgeville
# Processing Record 244 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=alice springs
# Processing Record 245 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=east london
# Processing Record 246 | Xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=xining
# Processing Record 247 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=comodoro rivadavia
# Processing Record 248 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=mar del plata
# Processing Record 249 | Bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=bilibino
# Processing Record 250 | Juneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=juneau
# Processing Record 251 | Biltine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=biltine
# Processing Record 252 | Junin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=junin
# City not found. Skipping...
# Processing Record 253 | Yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=yumen
# Processing Record 254 | Praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=praia
# City not found. Skipping...
# Processing Record 255 | Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=nouadhibou
# Processing Record 256 | Gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=gat
# Processing Record 257 | San Ramon de la Nueva Oran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=san ramon de la nueva oran
# Processing Record 258 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=makakilo city
# City not found. Skipping...
# Processing Record 259 | Ust-Maya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ust-maya
# Processing Record 260 | Chabahar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=chabahar
# Processing Record 261 | Imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=imbituba
# City not found. Skipping...
# Processing Record 262 | Varnamo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=varnamo
# Processing Record 263 | Bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=bowen
# Processing Record 264 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=havre-saint-pierre
# Processing Record 265 | Santiago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=santiago
# Processing Record 266 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=te anau
# Processing Record 267 | Bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=bud
# Processing Record 268 | Dogondoutchi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=dogondoutchi
# Processing Record 269 | Chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=chapais
# Processing Record 270 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=vanimo
# Processing Record 271 | Tarakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=tarakan
# Processing Record 272 | Sinazongwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=sinazongwe
# Processing Record 273 | Payo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=payo
# Processing Record 274 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=poum
# City not found. Skipping...
# Processing Record 275 | Ust-Ilimsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ust-ilimsk
# Processing Record 276 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=port blair
# Processing Record 277 | Timbuktu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=tombouctou
# Processing Record 278 | Itanagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=itanagar
# Processing Record 279 | Floro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=floro
# Processing Record 280 | Kawalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kawalu
# Processing Record 281 | Bamiantong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=bamiantong
# Processing Record 282 | Hailar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hailar
# Processing Record 283 | Torma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=torma
# Processing Record 284 | Sirsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=sirsa
# Processing Record 285 | Kitui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kitui
# Processing Record 286 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=new norfolk
# Processing Record 287 | Nicoya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=nicoya
# Processing Record 288 | San Juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=san juan
# Processing Record 289 | Clarence Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=clarence town
# Processing Record 290 | Bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=bonthe
# Processing Record 291 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=saint-philippe
# Processing Record 292 | Seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=seoul
# City not found. Skipping...
# Processing Record 293 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=padang
# Processing Record 294 | Los Alamos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=los alamos
# Processing Record 295 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=vila velha
# Processing Record 296 | Helena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=helena
# Processing Record 297 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=egvekinot
# Processing Record 298 | Bahia Blanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=bahia blanca
# Processing Record 299 | Machinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=machinga
# Processing Record 300 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kaitangata
# City not found. Skipping...
# Processing Record 301 | Mersing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=mersing
# Processing Record 302 | Taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=taltal
# City not found. Skipping...
# Processing Record 303 | Abapo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=abapo
# City not found. Skipping...
# Processing Record 304 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=constitucion
# Processing Record 305 | Maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=maceio
# Processing Record 306 | Springdale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=springdale
# Processing Record 307 | Liwale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=liwale
# Processing Record 308 | Burgeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=burgeo
# Processing Record 309 | Angoche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=angoche
# Processing Record 310 | Coolum Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=coolum beach
# Processing Record 311 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=lorengau
# Processing Record 312 | Mazagao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=mazagao
# Processing Record 313 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hofn
# Processing Record 314 | Macusani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=macusani
# Processing Record 315 | Fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=fare
# Processing Record 316 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=richards bay
# City not found. Skipping...
# Processing Record 317 | Santa Maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=santa maria
# Processing Record 318 | Panama City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=panama city
# Processing Record 319 | Kriva Palanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kriva palanka
# Processing Record 320 | Winfield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=winfield
# Processing Record 321 | Adiake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=adiake
# Processing Record 322 | Bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=bilma
# Processing Record 323 | Saint-Pierre
# ...
# Processing Record 460 | Ewa Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ewa beach
# Processing Record 461 | Hare Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hare bay
# Processing Record 462 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=vao
# Processing Record 463 | Shumskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=shumskiy
# Processing Record 464 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=katsuura
# Processing Record 465 | Gimli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=gimli
# Processing Record 466 | Igbo Ora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=igbo ora
# Processing Record 467 | Gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=gamba
# Processing Record 468 | Kalengwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kalengwa
# Processing Record 469 | Ovalle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ovalle
# Processing Record 470 | Hlobyne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hlobyne
# Processing Record 471 | Polunochnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=polunochnoye
# City not found. Skipping...
# Processing Record 472 | Taksimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=taksimo
# Processing Record 473 | Opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=opuwo
# Processing Record 474 | Ostersund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ostersund
# City not found. Skipping...
# Processing Record 475 | Rzhaksa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=rzhaksa
# Processing Record 476 | Dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=dwarka
# Processing Record 477 | Turayf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=turayf
# Processing Record 478 | Shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=shimoda
# Processing Record 479 | Wajir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=wajir
# Processing Record 480 | Wasilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=wasilla
# Processing Record 481 | Kilindoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kilindoni
# City not found. Skipping...
# Processing Record 482 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=tautira
# Processing Record 483 | Pendleton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=pendleton
# Processing Record 484 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=narsaq
# Processing Record 485 | Kodra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kodra
# Processing Record 486 | Morros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=morros
# Processing Record 487 | Sueyoshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=sueyoshi
# Processing Record 488 | Kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kirakira
# Processing Record 489 | Brandfort
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=brandfort
# Processing Record 490 | Ekibastuz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ekibastuz
# Processing Record 491 | Boca do Acre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=boca do acre
# Processing Record 492 | Hlinsko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hlinsko
# Processing Record 493 | Umm Lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=umm lajj
# City not found. Skipping...
# Processing Record 494 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=tilichiki
# Processing Record 495 | Kiryas Joel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kiryas joel
# Processing Record 496 | Ciudad Bolivar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ciudad bolivar
# Processing Record 497 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=port macquarie
# City not found. Skipping...
# Processing Record 498 | Marienburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=marienburg
# Processing Record 499 | Xinon Neron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=xinon neron
# Processing Record 500 | Stilfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=stilfontein
# Processing Record 501 | Yantal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=yantal
# Processing Record 502 | Bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=bereda
# Processing Record 503 | Namie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=namie
# Processing Record 504 | Guhagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=guhagar
# Processing Record 505 | Taitung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=taitung
# City not found. Skipping...
# Processing Record 506 | Kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kupang
# Processing Record 507 | Kuching
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kuching
# Processing Record 508 | Lufilufi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=lufilufi
# Processing Record 509 | Mutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=mutum
# Processing Record 510 | La Rioja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=la rioja
# City not found. Skipping...
# Processing Record 511 | Tomakomai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=tomakomai
# Processing Record 512 | Saint-Joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=saint-joseph
# Processing Record 513 | Khed Brahma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=khed brahma
# Processing Record 514 | Juruti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=juruti
# Processing Record 515 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=quatre cocos
# Processing Record 516 | Redlands
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=redlands
# Processing Record 517 | Korablino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=korablino
# Processing Record 518 | Kayerkan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kayerkan
# Processing Record 519 | Vung Tau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=vung tau
# Processing Record 520 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=pangnirtung
# Processing Record 521 | Auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=auki
# Processing Record 522 | Cangzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=cangzhou
# Processing Record 523 | Gladstone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=gladstone
# Processing Record 524 | Kumano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kumano
# Processing Record 525 | Parabel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=parabel
# Processing Record 526 | Yerofey Pavlovich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=yerofey pavlovich
# Processing Record 527 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=broome
# Processing Record 528 | Ak-Dovurak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ak-dovurak
# Processing Record 529 | Mehendiganj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=mehendiganj
# Processing Record 530 | Tyrma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=tyrma
# Processing Record 531 | Kashira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kashira
# Processing Record 532 | Mason City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=mason city
# Processing Record 533 | Dali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=dali
# City not found. Skipping...
# Processing Record 534 | Nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=nizwa
# Processing Record 535 | South Hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=south hill
# Processing Record 536 | Marrakesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=marrakesh
# Processing Record 537 | Peleduy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=peleduy
# Processing Record 538 | Kautokeino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kautokeino
# Processing Record 539 | Ligayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=ligayan
# Processing Record 540 | Trincomalee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=trincomalee
# Processing Record 541 | Biharamulo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=biharamulo
# Processing Record 542 | Nalut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=nalut
# Processing Record 543 | Almunecar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=almunecar
# Processing Record 544 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=bonavista
# City not found. Skipping...
# Processing Record 545 | Buenos Aires
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=buenos aires
# Processing Record 546 | Macau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=macau
# Processing Record 547 | Northport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=northport
# Processing Record 548 | Maple Creek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=maple creek
# Processing Record 549 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=lavrentiya
# Processing Record 550 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=vostok
# Processing Record 551 | Tarko-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=tarko-sale
# Processing Record 552 | Henderson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=henderson
# Processing Record 553 | Gumdag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=gumdag
# Processing Record 554 | Quthing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=quthing
# Processing Record 555 | Adelaide
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=adelaide
# Processing Record 556 | Atchison
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=atchison
# Processing Record 557 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=sao joao da barra
# Processing Record 558 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=hambantota
# Processing Record 559 | Farsund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=farsund
# Processing Record 560 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=half moon bay
# Processing Record 561 | Kati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kati
# Processing Record 562 | Dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=dukat
# City not found. Skipping...
# Processing Record 563 | Kuldur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=kuldur
# Processing Record 564 | Barinas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=barinas
# Processing Record 565 | Sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=sungaipenuh
# Processing Record 566 | Barra do Garcas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=barra do garcas
# Processing Record 567 | Linxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f63091978fbd2a8bf514153da1a47cac&q=linxia

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_dictionary = {
    "City": city,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": maxtemp,
    "Wind Speed":windspeed
}

# Create a data frame from dictionary
cities= pd.DataFrame(cities_dictionary)

# Display count of weather data values 
cities.count()

cities.to_csv(r'C:\Users\josep\RUTJC201904DATA3\hw\week6-python-apis\cities.csv')

# %%
cities.head()
# Out:
#      City  Cloudiness Country        Date  Humidity    Lat     Lng  Max Temp  \
# 0  linxia           0      NO  1562792478        75  71.03   27.85     48.20
# 1  linxia          75      CL  1562792479        93 -36.72  -73.12     53.60
# 2  linxia          83      AR  1562792247        66 -38.31  -60.23     52.90
# 3  linxia          14      RU  1562792449        76  61.28  108.01     60.45
# 4  linxia          37      CK  1562792269        78 -21.21 -159.78     75.20
#
#    Wind Speed
# 0        4.70
# 1        8.05
# 2        1.88
# 3        4.85
# 4       13.87

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(cities["Lat"], cities["Max Temp"])

plt.title('City Latitude vs. Max Temperature 06/25/2019')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cities['Lat'], cities['Humidity'])

plt.title('City Latitude vs. Humidity 06/25/2019')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
# Out:
# Text(0, 0.5, 'Humidity (%)')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities['Lat'], cities['Cloudiness'])

plt.title('City Latitude vs. Cloudiness 06/25/2019')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
# Out:
# Text(0, 0.5, 'Cloudiness (%)')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities['Lat'], cities['Wind Speed']

plt.title('City Latitude vs. Windspeed 06/25/2019')
plt.xlabel('Latitude')
plt.ylabel('Windspeed')
# Out:
# Text(0, 0.5, 'Windspeed')
